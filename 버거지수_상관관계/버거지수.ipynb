# %%
import pandas as pd
pd.set_option('mode.chained_assignment',  None) # Warning 방지용
import numpy as np

lotte = pd.read_csv('./롯데리아_지역.csv', index_col=0, encoding='CP949', engine='python')

lotte.head() #작업내용 확인용 출력
# Out:
#     시도   군구     시도군구  lot
# 0  강원도  강릉시  강원도 강릉시    5
# 1  강원도  고성군  강원도 고성군    1
# 2  강원도  동해시  강원도 동해시    2
# 3  강원도  삼척시  강원도 삼척시    1
# 4  강원도  속초시  강원도 속초시    3

# %%
lotte = lotte.set_index("시도군구")

lotte.head()   #작업 확인용 출력
# Out:
#           시도   군구  lot
# 시도군구
# 강원도 강릉시  강원도  강릉시    5
# 강원도 고성군  강원도  고성군    1
# 강원도 동해시  강원도  동해시    2
# 강원도 삼척시  강원도  삼척시    1
# 강원도 속초시  강원도  속초시    3

# %%
mc = pd.read_csv('./맥도날드_지역.csv', index_col=0, encoding='CP949', engine='python')

mc.head() #작업내용 확인용 출력
# Out:
#     시도   군구     시도군구  mc
# 0  강원도  강릉시  강원도 강릉시   1
# 1  강원도  동해시  강원도 동해시   1
# 2  강원도  속초시  강원도 속초시   1
# 3  강원도  원주시  강원도 원주시   2
# 4  강원도  춘천시  강원도 춘천시   2

# %%
mc = mc.set_index("시도군구")

mc.head()   #작업 확인용 출력
# Out:
#           시도   군구  mc
# 시도군구
# 강원도 강릉시  강원도  강릉시   1
# 강원도 동해시  강원도  동해시   1
# 강원도 속초시  강원도  속초시   1
# 강원도 원주시  강원도  원주시   2
# 강원도 춘천시  강원도  춘천시   2

# %%
sub = pd.read_csv('./서브웨이_지역.csv', index_col=0, encoding='CP949', engine='python')

sub.head() #작업내용 확인용 출력
# Out:
#     시도    군구      시도군구  sub
# 0  강원도   태백시   강원도 태백시    1
# 1  경기도   고양시   경기도 고양시   19
# 2  경기도   광명시   경기도 광명시    3
# 3  경기도   군포시   경기도 군포시    2
# 4  경기도  남양주시  경기도 남양주시    1

# %%
sub = sub.set_index("시도군구")

sub.head()   #작업 확인용 출력
# Out:
#            시도    군구  sub
# 시도군구
# 강원도 태백시   강원도   태백시    1
# 경기도 고양시   경기도   고양시   19
# 경기도 광명시   경기도   광명시    3
# 경기도 군포시   경기도   군포시    2
# 경기도 남양주시  경기도  남양주시    1

# %%
king = pd.read_csv('./버거킹_지역.csv', index_col=0, encoding='CP949', engine='python')

king.head() #작업내용 확인용 출력
# Out:
#     시도   군구     시도군구  king
# 0  강원도  강릉시  강원도 강릉시     1
# 1  강원도  속초시  강원도 속초시     1
# 2  강원도  원주시  강원도 원주시     3
# 3  강원도  춘천시  강원도 춘천시     2
# 4  강원도  홍천군  강원도 홍천군     2

# %%
king = king.set_index("시도군구")

king.head()   #작업 확인용 출력
# Out:
#           시도   군구  king
# 시도군구
# 강원도 강릉시  강원도  강릉시     1
# 강원도 속초시  강원도  속초시     1
# 강원도 원주시  강원도  원주시     3
# 강원도 춘천시  강원도  춘천시     2
# 강원도 홍천군  강원도  홍천군     2

# %%
population = pd.read_excel('./data.xlsx')

population.head()    #작업 확인용 출력
# Out:
#   행정구역(시군구)별(1) 행정구역(시군구)별(2)  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 0            전국            소계  51847509   25862863   25984646
# 1         서울특별시            소계   9733509    4745088    4988421
# 2         서울특별시        　　　종로구    151215      73688      77527
# 3         서울특별시         　　　중구    126201      61946      64255
# 4         서울특별시        　　　용산구    229385     110701     118684

# %%
population = population.rename(columns = {'행정구역(시군구)별(1)': '시도', '행정구역(시군구)별(2)': '군구'}) #컬럼이름 변경

population.head()  #작업 확인용 출력
# Out:
#       시도      군구  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 0     전국      소계  51847509   25862863   25984646
# 1  서울특별시      소계   9733509    4745088    4988421
# 2  서울특별시  　　　종로구    151215      73688      77527
# 3  서울특별시   　　　중구    126201      61946      64255
# 4  서울특별시  　　　용산구    229385     110701     118684

# %%
# '군구' 컬럼에서 공백 제거하기
for element in range(0,len(population)):
      population['군구'][element] = population['군구'][element].strip()

# %%
# '시도'와 '군구'를 연결하여 '시도군구' 컬럼 추가
population['시도군구']= population.apply(lambda r: r['시도'] + ' ' + r['군구'], axis=1)

population.head()  #작업 확인용 출력
# Out:
#       시도   군구  총인구수 (명)  남자인구수 (명)  여자인구수 (명)       시도군구
# 0     전국   소계  51847509   25862863   25984646      전국 소계
# 1  서울특별시   소계   9733509    4745088    4988421   서울특별시 소계
# 2  서울특별시  종로구    151215      73688      77527  서울특별시 종로구
# 3  서울특별시   중구    126201      61946      64255   서울특별시 중구
# 4  서울특별시  용산구    229385     110701     118684  서울특별시 용산구

# %%
population = population[population.군구 != '소계']

population.head()  #작업 확인용 출력
# Out:
#       시도   군구  총인구수 (명)  남자인구수 (명)  여자인구수 (명)       시도군구
# 2  서울특별시  종로구    151215      73688      77527  서울특별시 종로구
# 3  서울특별시   중구    126201      61946      64255   서울특별시 중구
# 4  서울특별시  용산구    229385     110701     118684  서울특별시 용산구
# 5  서울특별시  성동구    300410     147020     153390  서울특별시 성동구
# 6  서울특별시  광진구    351263     170164     181099  서울특별시 광진구

# %%
population = population.set_index("시도군구")

population.head()  #작업 확인용 출력
# Out:
#               시도   군구  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 시도군구
# 서울특별시 종로구  서울특별시  종로구    151215      73688      77527
# 서울특별시 중구   서울특별시   중구    126201      61946      64255
# 서울특별시 용산구  서울특별시  용산구    229385     110701     118684
# 서울특별시 성동구  서울특별시  성동구    300410     147020     153390
# 서울특별시 광진구  서울특별시  광진구    351263     170164     181099

# %%
addr_population_merge = pd.merge(population,lotte, on="시도군구",  how='inner')

addr_population_merge.head()   #작업 확인용 출력
# Out:
#             시도_x 군구_x  총인구수 (명)  남자인구수 (명)  여자인구수 (명)   시도_y 군구_y  lot
# 시도군구
# 서울특별시 종로구  서울특별시  종로구    151215      73688      77527  서울특별시  종로구    4
# 서울특별시 중구   서울특별시   중구    126201      61946      64255  서울특별시   중구    3
# 서울특별시 용산구  서울특별시  용산구    229385     110701     118684  서울특별시  용산구    7
# 서울특별시 성동구  서울특별시  성동구    300410     147020     153390  서울특별시  성동구    5
# 서울특별시 광진구  서울특별시  광진구    351263     170164     181099  서울특별시  광진구    9

# %%
addr_population_merge = pd.merge(addr_population_merge, king, on="시도군구" ,how='inner')

addr_population_merge.head()   #작업 확인용 출력
# Out:
#             시도_x 군구_x  총인구수 (명)  남자인구수 (명)  여자인구수 (명)   시도_y 군구_y  lot     시도  \
# 시도군구
# 서울특별시 종로구  서울특별시  종로구    151215      73688      77527  서울특별시  종로구    4  서울특별시
# 서울특별시 중구   서울특별시   중구    126201      61946      64255  서울특별시   중구    3  서울특별시
# 서울특별시 용산구  서울특별시  용산구    229385     110701     118684  서울특별시  용산구    7  서울특별시
# 서울특별시 성동구  서울특별시  성동구    300410     147020     153390  서울특별시  성동구    5  서울특별시
# 서울특별시 광진구  서울특별시  광진구    351263     170164     181099  서울특별시  광진구    9  서울특별시
#
#             군구  king
# 시도군구
# 서울특별시 종로구  종로구     4
# 서울특별시 중구    중구    10
# 서울특별시 용산구  용산구     3
# 서울특별시 성동구  성동구     1
# 서울특별시 광진구  광진구     4

# %%
addr_population_merge = pd.merge(addr_population_merge, sub, on="시도군구", how='inner')

addr_population_merge.head()   #작업 확인용 출력
# Out:
# <ipython-input-18-363d7651690c>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'군구_x', '시도_x'} in the result is deprecated and will raise a MergeError in a future version.
#   addr_population_merge = pd.merge(addr_population_merge, sub, on="시도군구", how='inner')
#             시도_x 군구_x  총인구수 (명)  남자인구수 (명)  여자인구수 (명)   시도_y 군구_y  lot   시도_x  \
# 시도군구
# 서울특별시 종로구  서울특별시  종로구    151215      73688      77527  서울특별시  종로구    4  서울특별시
# 서울특별시 중구   서울특별시   중구    126201      61946      64255  서울특별시   중구    3  서울특별시
# 서울특별시 용산구  서울특별시  용산구    229385     110701     118684  서울특별시  용산구    7  서울특별시
# 서울특별시 성동구  서울특별시  성동구    300410     147020     153390  서울특별시  성동구    5  서울특별시
# 서울특별시 광진구  서울특별시  광진구    351263     170164     181099  서울특별시  광진구    9  서울특별시
#
#           군구_x  king   시도_y 군구_y  sub
# 시도군구
# 서울특별시 종로구  종로구     4  서울특별시  종로구   10
# 서울특별시 중구    중구    10  서울특별시   중구   11
# 서울특별시 용산구  용산구     3  서울특별시  용산구    6
# 서울특별시 성동구  성동구     1  서울특별시  성동구    6
# ...

# %%
addr_population_merge = pd.merge(addr_population_merge, mc, on="시도군구", how='inner')

addr_population_merge.head()   #작업 확인용 출력
# Out:
#             시도_x 군구_x  총인구수 (명)  남자인구수 (명)  여자인구수 (명)   시도_y 군구_y  lot   시도_x  \
# 시도군구
# 서울특별시 종로구  서울특별시  종로구    151215      73688      77527  서울특별시  종로구    4  서울특별시
# 서울특별시 중구   서울특별시   중구    126201      61946      64255  서울특별시   중구    3  서울특별시
# 서울특별시 용산구  서울특별시  용산구    229385     110701     118684  서울특별시  용산구    7  서울특별시
# 서울특별시 성동구  서울특별시  성동구    300410     147020     153390  서울특별시  성동구    5  서울특별시
# 서울특별시 광진구  서울특별시  광진구    351263     170164     181099  서울특별시  광진구    9  서울특별시
#
#           군구_x  king   시도_y 군구_y  sub     시도   군구  mc
# 시도군구
# 서울특별시 종로구  종로구     4  서울특별시  종로구   10  서울특별시  종로구   8
# 서울특별시 중구    중구    10  서울특별시   중구   11  서울특별시   중구   4
# 서울특별시 용산구  용산구     3  서울특별시  용산구    6  서울특별시  용산구   2
# 서울특별시 성동구  성동구     1  서울특별시  성동구    6  서울특별시  성동구   2
# 서울특별시 광진구  광진구     4  서울특별시  광진구    9  서울특별시  광진구   2

# %%
local = addr_population_merge[['시도', '군구',  'mc','king','sub','lot', '총인구수 (명)']]

local.head()   #작업 확인용 출력
# Out:
#               시도   군구  mc  king  sub  lot  총인구수 (명)
# 시도군구
# 서울특별시 종로구  서울특별시  종로구   8     4   10    4    151215
# 서울특별시 중구   서울특별시   중구   4    10   11    3    126201
# 서울특별시 용산구  서울특별시  용산구   2     3    6    7    229385
# 서울특별시 성동구  서울특별시  성동구   2     1    6    5    300410
# 서울특별시 광진구  서울특별시  광진구   2     4    9    9    351263

# %%
local[local['군구'] == '동해시']
# Out:
# Empty DataFrame
# Columns: [시도, 군구, mc, king, sub, lot, 총인구수 (명)]
# Index: []

# %%
local['B_ratio'] = (local['mc']+local['sub']+local['king'])/ local['lot']
local.head()
# Out:
#               시도   군구  mc  king  sub  lot  총인구수 (명)   B_ratio
# 시도군구
# 서울특별시 종로구  서울특별시  종로구   8     4   10    4    151215  5.500000
# 서울특별시 중구   서울특별시   중구   4    10   11    3    126201  8.333333
# 서울특별시 용산구  서울특별시  용산구   2     3    6    7    229385  1.571429
# 서울특별시 성동구  서울특별시  성동구   2     1    6    5    300410  1.800000
# 서울특별시 광진구  서울특별시  광진구   2     4    9    9    351263  1.666667

# %%
grdp = pd.read_excel('./GRDP.xlsx')
grdp.head()    #작업 확인용 출력
# Out:
#       시도   군구       GRDP
# 0  서울특별시   소계  423742112
# 1  서울특별시  종로구   31868698
# 2  서울특별시   중구   54274488
# 3  서울특별시  용산구   12300317
# 4  서울특별시  성동구   11657151

# %%
# '군구' 컬럼에서 공백 제거하기
for element in range(0,len(grdp)):
      grdp['군구'][element] = grdp['군구'][element].strip()

# %%
# '시도'와 '군구'를 연결하여 '시도군구' 컬럼 추가
grdp['시도군구']= grdp.apply(lambda r: r['시도'] + ' ' + r['군구'], axis=1)

grdp.head()  #작업 확인용 출력
# Out:
#       시도   군구       GRDP       시도군구
# 0  서울특별시   소계  423742112   서울특별시 소계
# 1  서울특별시  종로구   31868698  서울특별시 종로구
# 2  서울특별시   중구   54274488   서울특별시 중구
# 3  서울특별시  용산구   12300317  서울특별시 용산구
# 4  서울특별시  성동구   11657151  서울특별시 성동구

# %%
grdp = grdp.set_index("시도군구")

grdp.head()  #작업 확인용 출력
# Out:
#               시도   군구       GRDP
# 시도군구
# 서울특별시 소계   서울특별시   소계  423742112
# 서울특별시 종로구  서울특별시  종로구   31868698
# 서울특별시 중구   서울특별시   중구   54274488
# 서울특별시 용산구  서울특별시  용산구   12300317
# 서울특별시 성동구  서울특별시  성동구   11657151

# %%
grdp = grdp[grdp.군구 != '소계']

grdp.head()  #작업 확인용 출력
# Out:
#               시도   군구      GRDP
# 시도군구
# 서울특별시 종로구  서울특별시  종로구  31868698
# 서울특별시 중구   서울특별시   중구  54274488
# 서울특별시 용산구  서울특별시  용산구  12300317
# 서울특별시 성동구  서울특별시  성동구  11657151
# 서울특별시 광진구  서울특별시  광진구   6342279

# %%
local_grdp =  pd.merge(grdp,local,  how='inner',  left_index=True, right_index=True)

local_grdp.head()
# Out:
#             시도_x 군구_x      GRDP   시도_y 군구_y  mc  king  sub  lot  총인구수 (명)  \
# 시도군구
# 서울특별시 종로구  서울특별시  종로구  31868698  서울특별시  종로구   8     4   10    4    151215
# 서울특별시 중구   서울특별시   중구  54274488  서울특별시   중구   4    10   11    3    126201
# 서울특별시 용산구  서울특별시  용산구  12300317  서울특별시  용산구   2     3    6    7    229385
# 서울특별시 성동구  서울특별시  성동구  11657151  서울특별시  성동구   2     1    6    5    300410
# 서울특별시 광진구  서울특별시  광진구   6342279  서울특별시  광진구   2     4    9    9    351263
#
#             B_ratio
# 시도군구
# 서울특별시 종로구  5.500000
# 서울특별시 중구   8.333333
# 서울특별시 용산구  1.571429
# 서울특별시 성동구  1.800000
# 서울특별시 광진구  1.666667

# %%
local_burger = local_grdp[['시도_x', '군구_x',  'mc','king','sub','lot','GRDP', '총인구수 (명)','B_ratio']]

local_burger.head()   #작업 확인용 출력
# Out:
#             시도_x 군구_x  mc  king  sub  lot      GRDP  총인구수 (명)   B_ratio
# 시도군구
# 서울특별시 종로구  서울특별시  종로구   8     4   10    4  31868698    151215  5.500000
# 서울특별시 중구   서울특별시   중구   4    10   11    3  54274488    126201  8.333333
# 서울특별시 용산구  서울특별시  용산구   2     3    6    7  12300317    229385  1.571429
# 서울특별시 성동구  서울특별시  성동구   2     1    6    5  11657151    300410  1.800000
# 서울특별시 광진구  서울특별시  광진구   2     4    9    9   6342279    351263  1.666667

# %%
local_burger = local_burger.rename(columns = {'시도_x': '시도', '군구_x': '군구','총인구수 (명)': '인구수' })
local_burger.head()
# Out:
#               시도   군구  mc  king  sub  lot      GRDP     인구수   B_ratio
# 시도군구
# 서울특별시 종로구  서울특별시  종로구   8     4   10    4  31868698  151215  5.500000
# 서울특별시 중구   서울특별시   중구   4    10   11    3  54274488  126201  8.333333
# 서울특별시 용산구  서울특별시  용산구   2     3    6    7  12300317  229385  1.571429
# 서울특별시 성동구  서울특별시  성동구   2     1    6    5  11657151  300410  1.800000
# 서울특별시 광진구  서울특별시  광진구   2     4    9    9   6342279  351263  1.666667

# %%
local_burger['GP'] = local_burger['GRDP'] / local_burger['인구수']
local_burger.head()
# Out:
#               시도   군구  mc  king  sub  lot      GRDP     인구수   B_ratio  \
# 시도군구
# 서울특별시 종로구  서울특별시  종로구   8     4   10    4  31868698  151215  5.500000
# 서울특별시 중구   서울특별시   중구   4    10   11    3  54274488  126201  8.333333
# 서울특별시 용산구  서울특별시  용산구   2     3    6    7  12300317  229385  1.571429
# 서울특별시 성동구  서울특별시  성동구   2     1    6    5  11657151  300410  1.800000
# 서울특별시 광진구  서울특별시  광진구   2     4    9    9   6342279  351263  1.666667
#
#                    GP
# 시도군구
# 서울특별시 종로구  210.750904
# 서울특별시 중구   430.063851
# 서울특별시 용산구   53.623022
# 서울특별시 성동구   38.804138
# 서울특별시 광진구   18.055642

# %%
local_burger.to_csv('./버거지수.csv', encoding='cp949')

# %%
from matplotlib import pyplot as plt
from matplotlib import rcParams, style
style.use('ggplot')

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
burger = local_burger[['king']]
burger = burger.sort_values('king', ascending = False)
plt.rcParams["figure.figsize"] = (25,5)
burger.plot(kind='bar', rot=90)
plt.show()

# %%
lotte = local_burger[['lot']]
lotte = lotte.sort_values('lot', ascending = False)
plt.rcParams["figure.figsize"] = (25,5)
lotte.plot(kind='bar', rot=90)
plt.show()

# %%
sub = local_burger[['sub']]
sub = sub.sort_values('sub', ascending = False)
plt.rcParams["figure.figsize"] = (25,5)
sub.plot(kind='bar', rot=90)
plt.show()

# %%
mc = local_burger[['mc']]
mc = mc.sort_values('mc', ascending = False)
plt.rcParams["figure.figsize"] = (25,5)
mc.plot(kind='bar', rot=90)
plt.show()

# %%
B_ratio = local_burger[['B_ratio']]
B_ratio = B_ratio.sort_values('B_ratio', ascending = False)
plt.rcParams["figure.figsize"] = (25,5)
B_ratio.plot(kind='bar', rot=90)
plt.show()

# %%
data_draw_korea = pd.read_csv('./data_draw_korea.csv', index_col=0, encoding='UTF-8', engine='python')

data_draw_korea.head()   #작업 확인용 출력
# Out:
#       인구수 shortName   x  y       면적 광역시도 행정구역
# 0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2   86747        동해  11  5   180.01  강원도  동해시
# 3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4   76733        속초   9  1   105.25  강원도  속초시

# %%
data_draw_korea['시도군구']= data_draw_korea.apply(lambda r: r['광역시도'] + ' ' + r['행정구역'], axis=1)

data_draw_korea.head()  #작업 확인용 출력
# Out:
#       인구수 shortName   x  y       면적 광역시도 행정구역     시도군구
# 0  202520        강릉  11  4  1040.07  강원도  강릉시  강원도 강릉시
# 1   25589    고성(강원)   9  0   664.19  강원도  고성군  강원도 고성군
# 2   86747        동해  11  5   180.01  강원도  동해시  강원도 동해시
# 3   63986        삼척  11  8  1185.80  강원도  삼척시  강원도 삼척시
# 4   76733        속초   9  1   105.25  강원도  속초시  강원도 속초시

# %%
korea = data_draw_korea[['광역시도','행정구역','x', 'y', '시도군구']]
korea.head()
# Out:
#   광역시도 행정구역   x  y     시도군구
# 0  강원도  강릉시  11  4  강원도 강릉시
# 1  강원도  고성군   9  0  강원도 고성군
# 2  강원도  동해시  11  5  강원도 동해시
# 3  강원도  삼척시  11  8  강원도 삼척시
# 4  강원도  속초시   9  1  강원도 속초시

# %%
korea = korea.set_index("시도군구")

korea.head()  #작업 확인용 출력
# Out:
#         광역시도 행정구역   x  y
# 시도군구
# 강원도 강릉시  강원도  강릉시  11  4
# 강원도 고성군  강원도  고성군   9  0
# 강원도 동해시  강원도  동해시  11  5
# 강원도 삼척시  강원도  삼척시  11  8
# 강원도 속초시  강원도  속초시   9  1

# %%
data_draw_korea = pd.merge(korea,local_burger,  how='outer',  left_index=True, right_index=True)

data_draw_korea.head()
# Out:
#         광역시도 행정구역   x  y   시도   군구  mc  king  sub  lot  GRDP  인구수  B_ratio  GP
# 시도군구
# 강원도 강릉시  강원도  강릉시  11  4  NaN  NaN NaN   NaN  NaN  NaN   NaN  NaN      NaN NaN
# 강원도 고성군  강원도  고성군   9  0  NaN  NaN NaN   NaN  NaN  NaN   NaN  NaN      NaN NaN
# 강원도 동해시  강원도  동해시  11  5  NaN  NaN NaN   NaN  NaN  NaN   NaN  NaN      NaN NaN
# 강원도 삼척시  강원도  삼척시  11  8  NaN  NaN NaN   NaN  NaN  NaN   NaN  NaN      NaN NaN
# 강원도 속초시  강원도  속초시   9  1  NaN  NaN NaN   NaN  NaN  NaN   NaN  NaN      NaN NaN

# %%
data_draw_korea.to_csv('./버거지수.csv', encoding='cp949')

# %%
BORDER_LINES = [
    [(3, 2), (5, 2), (5, 3), (9, 3), (9, 1)], # 인천
    [(2, 5), (3, 5), (3, 4), (8, 4), (8, 7), (7, 7), (7, 9), (4, 9), (4, 7), (1, 7)], # 서울
    [(1, 6), (1, 9), (3, 9), (3, 10), (8, 10), (8, 9),
     (9, 9), (9, 8), (10, 8), (10, 5), (9, 5), (9, 3)], # 경기도
    [(9, 12), (9, 10), (8, 10)], # 강원도
    [(10, 5), (11, 5), (11, 4), (12, 4), (12, 5), (13, 5),
     (13, 4), (14, 4), (14, 2)], # 충청남도
    [(11, 5), (12, 5), (12, 6), (15, 6), (15, 7), (13, 7),
     (13, 8), (11, 8), (11, 9), (10, 9), (10, 8)], # 충청북도
    [(14, 4), (15, 4), (15, 6)], # 대전시
    [(14, 7), (14, 9), (13, 9), (13, 11), (13, 13)], # 경상북도
    [(14, 8), (16, 8), (16, 10), (15, 10),
     (15, 11), (14, 11), (14, 12), (13, 12)], # 대구시
    [(15, 11), (16, 11), (16, 13)], # 울산시
    [(17, 1), (17, 3), (18, 3), (18, 6), (15, 6)], # 전라북도
    [(19, 2), (19, 4), (21, 4), (21, 3), (22, 3), (22, 2), (19, 2)], # 광주시
    [(18, 5), (20, 5), (20, 6)], # 전라남도
    [(16, 9), (18, 9), (18, 8), (19, 8), (19, 9), (20, 9), (20, 10)], # 부산시
]

# %%
def draw_blockMap(blockedMap, targetData, title, color ):
    whitelabelmin = (max(blockedMap[targetData]) - min(blockedMap[targetData])) * 0.25 + min(blockedMap[targetData])

    datalabel = targetData

    vmin = 0
    vmax = 9

    mapdata = blockedMap.pivot(index='y', columns='x', values=targetData)
    masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)
    
    plt.figure(figsize=(8, 13))
    plt.title(title)
    plt.pcolor(masked_mapdata, vmin=vmin, vmax=vmax, cmap=color, edgecolor='#aaaaaa', linewidth=0.5)

    # 지역 이름 표시
    for idx, row in blockedMap.iterrows():
        annocolor = 'white' if row[targetData] > whitelabelmin else 'black'
    
        # 광역시는 구 이름이 겹치는 경우가 많아서 시단위 이름도 같이 표시한다. (중구, 서구)
        if row['광역시도'].endswith('시') and not row['광역시도'].startswith('세종'):
            dispname = '{}\n{}'.format(row['광역시도'][:2], row['행정구역'][:-1])
            if len(row['행정구역']) <= 2:
                dispname += row['행정구역'][-1]
        else:
            dispname = row['행정구역'][:-1]

        # 서대문구, 서귀포시 같이 이름이 3자 이상인 경우에 작은 글자로 표시한다.
        if len(dispname.splitlines()[-1]) >= 3:
            fontsize, linespacing = 9.5, 1.5
        else:
            fontsize, linespacing = 11, 1.2

        plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight='bold',
                     fontsize=fontsize, ha='center', va='center', color=annocolor,
                     linespacing=linespacing)
    
    # 시도 경계 그린다.
    for path in BORDER_LINES:
        ys, xs = zip(*path)
        plt.plot(xs, ys, c='black', lw=4)

    plt.gca().invert_yaxis()
    #plt.gca().set_aspect(1)
    plt.axis('off')
    
    cb = plt.colorbar(shrink=.1, aspect=10)
    cb.set_label(datalabel)

    plt.tight_layout()
    
    plt.savefig('./' + 'blockMap_' + targetData + '.png')
                      
    
    plt.show()

# %%
draw_blockMap(data_draw_korea, 'B_ratio', '행정구역별 버거지수', 'Blues')
